# %%
print('Hello, Python!')
# Out:
# Hello, Python!

# %%
import sys
print(sys.version)
# Out:
# 3.7.10 (default, Feb 26 2021, 18:47:35)
# [GCC 7.3.0]

# %%
# Practice on writing comments

print('Hello, Python!') # This line prints a string
# print('Hi')
# Out:
# Hello, Python!

# %%
# Print string as error message

frint("Hello, Python!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-313a1769a8a5> in <module>
#       1 # Print string as error message
#       2
# ----> 3 frint("Hello, Python!")
#
# NameError: name 'frint' is not defined

# %%
# Try to se build in error message

print("Hello, Python!")
# Out:
# Hello, Python!

# %%
# Print string and error to see the running order

print("This will be printed")
frint("this will cause an error")
print("This will NOT be printed")
# Out:
# This will be printed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-058f5a259df2> in <module>
#       2
#       3 print("This will be printed")
# ----> 4 frint("this will cause an error")
#       5 print("This will NOT be printed")
#
# NameError: name 'frint' is not defined

# %%
type(12)
# Out:
# int

# %%
type(2.4)
# Out:
# float

# %%
type("hello, Python 101!")
# Out:
# str

# %%
type(-1)
# Out:
# int

# %%
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
type(0.56)
# Out:
# float

# %%
# Verify that this is an integer
type(2)
# Out:
# int

# %%
# Convert 2 to a float
float(2)
# Out:
# 2.0

# %%
# Convert integer 2 to a float and check its type
type(float(2))
# Out:
# float

# %%
#Casting 1.1 to integer will result in loss of information
int(1.1)
# Out:
# 1

# %%
#Convert a string to an integer
int('1')
# Out:
# 1

# %%
# Convert a string into an integer with error
int('1 or 2 people')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-56968935ff9e> in <module>
#       1 # Convert a string into an integer with error
# ----> 2 int('1 or 2 people')
#
# ValueError: invalid literal for int() with base 10: '1 or 2 people'

# %%
# Convert the string "1.2" into a float
float('1.2')
# Out:
# 1.2

# %%
# Convert an integer to a string
str(1)
# Out:
# '1'

# %%
# Convert a float to a string
str(1.2)
# Out:
# '1.2'

# %%
# Value true
True
# Out:
# True

# %%
# Value False
False
# Out:
# False

# %%
#Type of True
type(True)
# Out:
# bool

# %%
#Type of False
type(False)
# Out:
# bool

# %%
#Convert True to int
int(True)
# Out:
# 1

# %%
# Convert 1 to boolean
bool(1)
# Out:
# True

# %%
# Convert 0 to boolean
bool(0)
# Out:
# False

# %%
#Convert True to float
float(True)
# Out:
# 1.0

# %%
25//6
# Out:
# 4

# %%
x=4+20+60+8

# %%
x
# Out:
# 92

# %%
y=x/60

# %%
y
# Out:
# 1.5333333333333334

# %%
x=x60
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e659960facda> in <module>
# ----> 1 x=x60
#
# NameError: name 'x60' is not defined

# %%
x=x/60

# %%
x
# Out:
# 1.5333333333333334

# %%
# Name the variables meaningfully

total_min=43+42+57 # Total Length of albums in minutes
total_min
# Out:
# 142

# %%
# Name the variables meaningfully

total_hours=total_min / 60 # Total length of albums in hours
total_hours
# Out:
# 2.3666666666666667

# %%
# Complicate expression
total_hours=(43+42+57)/60 # Total hours in a single expression
total_hours
# Out:
# 2.3666666666666667

# %%
x=3+2*2
x
# Out:
# 7

# %%
y=(3+2)*2
y
# Out:
# 10

# %%
z=x+y
z
# Out:
# 17
